# %% [markdown]
# # Reinforcement Learning - Monte Carlo
# If you want to test/submit your solution **restart the kernel, run all cells and submit the mc_autograde.py file into codegrade.**

# %%
# This cell imports %%execwritefile command (executes cell and writes it into file). 
# All cells that start with %%execwritefile should be in mc_autograde.py file after running all cells.
from custommagics import CustomMagics
get_ipython().register_magics(CustomMagics)

# %%
# %%execwritefile mc_autograde.py
# import numpy as np
# from collections import defaultdict
# from tqdm import tqdm as _tqdm
#
# def tqdm(*args, **kwargs):
#     return _tqdm(*args, **kwargs, mininterval=1)  # Safety, do not overflow buffer
# Out:
# Overwriting mc_autograde.py

# %%
import matplotlib.pyplot as plt
import sys


# %matplotlib inline

assert sys.version_info[:3] >= (3, 6, 0), "Make sure you have Python 3.6 installed!"

# %% [markdown]
# ## 1. Monte Carlo Prediction

# %% [markdown]
# For the Monte Carlo Prediction we will look at the Blackjack game (Example 5.1 from the book), for which the `BlackjackEnv` is implemented in `blackjack.py`. Note that compared to the gridworld, the state is no longer a single integer, which is why we use a dictionary to represent the value function instead of a numpy array. By using `defaultdict`, each state gets a default value of 0.

# %%
from blackjack import BlackjackEnv
env = BlackjackEnv()

# %% [markdown]
# For the Monte Carlo algorithm, we no longer have transition probabilities and we need to *interact* with the environment. This means that we start an episode by using `env.reset` and send the environment actions via `env.step` to observe the reward and next observation (state).

# %%
# So let's have a look at what we can do in general with an environment...
import gym
# ?gym.Env

# %%
# ?env

# %%
# We can also look at the documentation/implementation of a method
# ?env.step

# %%
??BlackjackEnv

# %% [markdown]
# A very simple policy for Blackjack is to *stick* if we have 20 or 21 points and *hit* otherwise. We want to know how good this policy is. This policy is *deterministic* and therefore a function that maps an observation to a single action. Technically, we can implement this as a dictionary , a function or a class with a function, where we use the last option. Moreover, it is often useful (as you will see later) to implement a function that returns  the probability $\pi(a|s)$ for the state action pair (the probability that this policy would perform certain action in given state). We group these two functions in a policy class. To get started, let's implement this simple policy for BlackJack.

# %%
# %%execwritefile -a mc_autograde.py
#
# class SimpleBlackjackPolicy(object):
#     """
#     A simple BlackJack policy that sticks with 20 or 21 points and hits otherwise.
#     """
#     def get_probs(self, states, actions):
#         """
#         This method takes a list of states and a list of actions and returns a numpy array that contains a probability
#         of perfoming action in given state for every corresponding state action pair.
#
#         Args:
#             states: a list of states.
#             actions: a list of actions.
#
#         Returns:
#             Numpy array filled with probabilities (same length as states and actions)
#         """
#         probs = np.zeros(len(states))
#         for i in range(len(states)):
#             if states[i][0] == 20 or states[i][0] == 21: # If sum is 20 or 21
#                 if actions[i] == 0:
#                     probs[i] = 1. # Action 0 (sick) 100% prob, so 0% action 1
#                 else:
#                     probs[i] = 0.
#             else:
#                 if actions[i] == 0:
#                     probs[i] = 0.
#                 else:
#                     probs[i] = 1. # Action 1 (hit) 100% prob
#
#         return np.array(probs)
#
#     def sample_action(self, state):
#         """
#         This method takes a state as input and returns an action sampled from this policy.
#
#         Args:
#             state: current state
#
#         Returns:
#             An action (int).
#         """
#         actions = [0, 1]
#         probs = self.get_probs([state, state], actions)
#         [action] = np.random.choice(actions, 1, p=probs)
#         return action
# Out:
# Appending to mc_autograde.py

# %%
# Let's check if it makes sense
env = BlackjackEnv()
s = env.reset()
policy = SimpleBlackjackPolicy()
print("State: {}\nSampled Action: {}\nProbabilities [stick, hit]: {}".format(s, policy.sample_action(s), policy.get_probs([s,s],[0,1])))
# Out:
# State: (21, 2, True)
# Sampled Action: 0
# Probabilities [stick, hit]: [1. 0.]

# %% [markdown]
# Since there are multiple algorithms which require data from single episode (or multiple episodes) it is often useful to write a routine that will sample a single episode. This will save us some time later. Implement a *sample_episode* function which uses environment and policy to sample a single episode.

# %%
# %%execwritefile -a mc_autograde.py
#
# def sample_episode(env, policy):
#     """
#     A sampling routine. Given environment and a policy samples one episode and returns states, actions, rewards
#     and dones from environment's step function and policy's sample_action function as lists.
#
#     Args:
#         env: OpenAI gym environment.
#         policy: A policy which allows us to sample actions with its sample_action method.
#
#     Returns:
#         Tuple of lists (states, actions, rewards, dones). All lists should have same length.
#         Hint: Do not include the state after the termination in the list of states.
#     """
#
#     states = []
#     actions = []
#     rewards = []
#     dones = []
#
#     state = env.reset()
#     states.append(state)
#
#     while True:
#
#         action = policy.sample_action(state)
#         observation, reward, done, info = env.step(action)
#
#         actions.append(action)
#         rewards.append(reward)
#         dones.append(done)
#
#         if done:
#             return states, actions, rewards, dones
#
#         states.append(observation)
#         state = observation
# Out:
# Appending to mc_autograde.py

# %%
# Let's sample some episodes
env = BlackjackEnv()
policy = SimpleBlackjackPolicy()
for episode in range(3):
    trajectory_data = sample_episode(env, policy)
    print("Episode {}:\nStates {}\nActions {}\nRewards {}\nDones {}\n".format(episode,*trajectory_data))
# Out:
# Episode 0:
# States [(19, 10, False), (21, 10, False)]
# Actions [1, 0]
# Rewards [0, 1]
# Dones [False, True]
#
# Episode 1:
# States [(18, 4, False), (20, 4, False)]
# Actions [1, 0]
# Rewards [0, 1]
# Dones [False, True]
#
# Episode 2:
# States [(19, 4, False)]
# Actions [1]
# Rewards [-1]
# Dones [True]

# %% [markdown]
# Now implement the MC prediction algorithm (either first visit or every visit). Hint: you can use `for i in tqdm(range(num_episodes))` to show a progress bar. Use the sampling function from above to sample data from a single episode.

# %%
# %%execwritefile -a mc_autograde.py
#
# def mc_prediction(env, policy, num_episodes, discount_factor=1.0, sampling_function=sample_episode):
#     """
#     Monte Carlo prediction algorithm. Calculates the value function
#     for a given policy using sampling.
#
#     Args:
#         env: OpenAI gym environment.
#         policy: A policy which allows us to sample actions with its sample_action method.
#         num_episodes: Number of episodes to sample.
#         discount_factor: Gamma discount factor.
#         sampling_function: Function that generates data from one episode.
#
#     Returns:
#         A dictionary that maps from state -> value.
#         The state is a tuple and the value is a float.
#     """
#
#     # Keeps track of current V and count of returns for each state
#     # to calculate an update.
#     V = defaultdict(float)
#     returns_count = defaultdict(float)
#
#     returns_total = defaultdict(float)
#
#     for i in tqdm(range(num_episodes)):
#
#         states, actions, rewards, dones = sampling_function(env, policy)
#         G = 0
#
#         for step in range(len(actions)-1, -1, -1): # A_{t-1}, R_{t}
#
#             state = states[step]
#             G = discount_factor*G + rewards[step]
#
#             if state not in states[0:step]:
#                 returns_total[state] += G
#                 returns_count[state] += 1
#                 V[state] = returns_total[state]/returns_count[state]
#
#     return V
# Out:
# Appending to mc_autograde.py

# %%
V_10k = mc_prediction(env, SimpleBlackjackPolicy(), num_episodes=10000)
print(V_10k)
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 6163.77it/s]
# defaultdict(<class 'float'>, {(19, 5, False): -0.7247706422018348, (18, 5, False): -0.6274509803921569, (19, 6, False): -0.7653061224489796, (17, 10, False): -0.735981308411215, (12, 10, False): -0.6105263157894737, (18, 3, False): -0.79, (14, 3, False): -0.6630434782608695, (21, 10, False): 0.9087591240875912, (19, 10, False): -0.7813852813852814, (12, 9, False): -0.6862745098039216, (21, 10, True): 0.9069767441860465, (17, 3, False): -0.6782608695652174, (18, 10, False): -0.7569892473118279, (12, 3, False): -0.6, (18, 9, False): -0.6129032258064516, (17, 6, False): -0.6842105263157895, (21, 9, False): 0.9459459459459459, (19, 9, False): -0.8160919540229885, (18, 2, False): -0.8080808080808081, (15, 2, False): -0.7289719626168224, (13, 2, False): -0.6025641025641025, (20, 8, False): 0.773972602739726, (15, 8, False): -0.44954128440366975, (16, 8, True): -0.3333333333333333, (20, 5, False): 0.7746478873239436, (13, 5, False): -0.5051546391752577, (14, 7, False): -0.6210526315789474, (20, 2, False): 0.6540880503144654, (17, 2, False): -0.6701030927835051, (14, 2, False): -0.4777777777777778, (19, 3, False): -0.7586206896551724, (20, 2, True): 0.65, (20, 3, False): 0.6975308641975309, (14, 10, False): -0.6237113402061856, (21, 6, False): 0.948051948051948, (14, 8, False): -0.6309523809523809, (14, 8, True): -0.09090909090909091, (20, 8, True): 0.8333333333333334, (21, 5, False): 0.8823529411764706, (15, 5, False): -0.5247524752475248, (20, 9, False): 0.6912751677852349, (18, 8, False): -0.7326732673267327, (21, 2, True): 0.9361702127659575, (19, 4, False): -0.7264957264957265, (14, 4, False): -0.5686274509803921, (16, 7, False): -0.78, (12, 8, False): -0.6138613861386139, (21, 2, False): 0.9324324324324325, (12, 2, False): -0.40540540540540543, (20, 4, False): 0.6753246753246753, (19, 8, True): -0.5384615384615384, (13, 8, True): -0.3333333333333333, (13, 6, False): -0.59375, (18, 6, True): -0.8947368421052632, (15, 9, False): -0.6326530612244898, (13, 7, False): -0.6063829787234043, (18, 7, True): -1.0, (16, 7, True): -0.2, (18, 4, False): -0.6796116504854369, (19, 9, True): -0.4444444444444444, (16, 9, True): -0.1, (17, 10, True): -0.24, (15, 4, False): -0.5287356321839081, (15, 3, False): -0.6986301369863014, (16, 3, True): -0.3333333333333333, (20, 10, False): 0.4482758620689655, (13, 10, False): -0.5748663101604278, (16, 10, False): -0.727710843373494, (18, 7, False): -0.76, (18, 6, False): -0.6595744680851063, (20, 6, False): 0.8091603053435115, (17, 4, False): -0.61, (21, 4, False): 0.9047619047619048, (13, 1, False): -0.7575757575757576, (21, 5, True): 0.7692307692307693, (12, 5, False): -0.40816326530612246, (20, 10, True): 0.39759036144578314, (18, 1, False): -0.7692307692307693, (14, 1, False): -0.6373626373626373, (13, 3, False): -0.6071428571428571, (20, 1, False): 0.13068181818181818, (15, 10, False): -0.6684491978609626, (21, 3, False): 0.9583333333333334, (19, 8, False): -0.6611570247933884, (16, 6, False): -0.6607142857142857, (21, 7, False): 0.8703703703703703, (19, 7, False): -0.696969696969697, (19, 7, True): -0.06666666666666667, (17, 7, True): 0.0, (17, 8, False): -0.638095238095238, (14, 5, False): -0.6804123711340206, (17, 5, True): -0.8888888888888888, (17, 9, False): -0.8613861386138614, (17, 5, False): -0.6470588235294118, (16, 8, False): -0.6344086021505376, (15, 6, False): -0.603448275862069, (15, 10, True): -0.425, (17, 1, False): -0.7304347826086957, (14, 9, False): -0.5913978494623656, (21, 6, True): 0.8863636363636364, (15, 7, False): -0.5636363636363636, (12, 7, False): -0.46938775510204084, (21, 3, True): 0.8974358974358975, (12, 4, False): -0.5853658536585366, (19, 4, True): -0.2222222222222222, (15, 4, True): 0.0, (18, 10, True): -0.37037037037037035, (21, 7, True): 0.975609756097561, (17, 7, False): -0.71, (21, 8, True): 0.9166666666666666, (21, 1, False): 0.711864406779661, (16, 1, False): -0.7843137254901961, (17, 1, True): -0.35294117647058826, (12, 1, False): -0.5543478260869565, (21, 9, ...

# %% [markdown]
# Now make *4 plots* like Figure 5.1 in the book. You can either make 3D plots or heatmaps. Make sure that your results look similar to the results in the book. Give your plots appropriate titles, axis labels, etc.

# %%
# %%time
# Let's run your code one time
V_10k = mc_prediction(env, SimpleBlackjackPolicy(), num_episodes=10000)
test = np.array([j for j in V_10k.values()])
print(np.min(test))
print(np.max(test))
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5942.25it/s]
# -1.0
# 0.9848484848484849
# CPU times: user 1.69 s, sys: 0 ns, total: 1.69 s
# Wall time: 1.68 s

# %%
V_500k = mc_prediction(env, SimpleBlackjackPolicy(), num_episodes=500000)
# Out:
# 100%|██████████| 500000/500000 [01:12<00:00, 6878.93it/s]

# %%
# Usable ace 10k
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure(0)
ax = fig.add_subplot(111, projection='3d')
X = np.arange(min([int(i[0]) for i in V_10k.keys()]), max([int(i[0])for i in V_10k.keys()])+1)
Y = np.arange(min([i[1] for i in V_10k.keys()]), max([i[1] for i in V_10k.keys()])+1)
Z = np.zeros([len(X), len(Y), 2])

for i, x in enumerate(X):
    for j,y in enumerate(Y):
        for k,z in enumerate([False, True]):
              Z[i, j, k] = V_10k[x, y, z]

X, Y = np.meshgrid(X, Y)
ax.plot_surface(X, Y, Z[:, :, 1])

ax.set_title('After 10K episodes, usable ace')
ax.set_zlim(-1, 1)
ax.set_xlabel("player")
ax.set_ylabel("dealer")
# Out:
# Text(0.5, 0, 'dealer')

# %%
# No usable ace 10k
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(111, projection='3d')

ax1.plot_surface(X, Y, Z[:, :, 0])

ax1.set_title('After 10K episodes, no usable ace')
ax1.set_zlim(-1, 1)
ax1.set_xlabel("player")
ax1.set_ylabel("dealer")
# Out:
# Text(0.5, 0, 'dealer')

# %%
# Usable ace 500k
fig2 = plt.figure(2)
ax2 = fig2.add_subplot(111, projection='3d')
X = np.arange(min([int(i[0]) for i in V_500k.keys()]), max([int(i[0])for i in V_500k.keys()])+1)
Y = np.arange(min([i[1] for i in V_500k.keys()]), max([i[1] for i in V_500k.keys()])+1)
Z = np.zeros([len(X), len(Y), 2])

for i, x in enumerate(X):
    for j,y in enumerate(Y):
        for k,z in enumerate([False, True]):
              Z[i, j, k] = V_500k[x, y, z]

X, Y = np.meshgrid(X, Y)
ax2.plot_surface(X, Y, Z[:, :, 1])

ax2.set_title('After 10K episodes, usable ace')
ax2.set_zlim(-1, 1)
ax2.set_xlabel("player")
ax2.set_ylabel("dealer")
ax2.set_title('After 500K episodes, usable ace')
# Out:
# Text(0.5, 0.8464, 'After 500K episodes, usable ace')

# %%
# No usable ace 500K
fig3 = plt.figure(3)
ax3 = fig3.add_subplot(111, projection='3d')

ax3.plot_surface(X, Y, Z[:, :, 0])

ax3.set_title('After 500K episodes, no usable ace')
ax3.set_zlim(-1, 1)
ax3.set_xlabel("player")
ax3.set_ylabel("dealer")
# Out:
# Text(0.5, 0, 'dealer')

# %% [markdown]
# ## 2. Off-policy Monte Carlo prediction
# In real world, it is often beneficial to learn from the experience of others in addition to your own. For example, you can probably infer that running off the cliff with a car is a bad idea if you consider what "return" people who have tried it received.
#
# Similarly, we can benefit from the experience of other agents in reinforcement learning. In this exercise we will use off-policy monte carlo to estimate the value function of our target policy using the experience from a different behavior policy. Our target policy will be the simple policy defined above (stick if we have *20* or *21* points) and we will use a random policy that randomly chooses to stick or hit (both with 50% probability) as a behavior policy. As a first step, implement a random BlackJack policy.

# %%
# %%execwritefile -a mc_autograde.py
#
# class RandomBlackjackPolicy(object):
#     """
#     A random BlackJack policy.
#     """
#     def get_probs(self, states, actions):
#         """
#         This method takes a list of states and a list of actions and returns a numpy array that contains
#         a probability of perfoming action in given state for every corresponding state action pair.
#
#         Args:
#             states: a list of states.
#             actions: a list of actions.
#
#         Returns:
#             Numpy array filled with probabilities (same length as states and actions)
#         """
#         probs = np.zeros(len(states))
#         probs.fill(0.5)
#         return np.array(probs)
#
#     def sample_action(self, state):
#         """
#         This method takes a state as input and returns an action sampled from this policy.
#
#         Args:
#             state: current state
#
#         Returns:
#             An action (int).
#         """
#         actions = [0, 1]
#         probs = self.get_probs([state, state], actions)
#         [action] = np.random.choice(actions, 1, p=probs)
#         return action
# Out:
# Appending to mc_autograde.py

# %%
# Let's check if it makes sense
env = BlackjackEnv()
s = env.reset()
policy = RandomBlackjackPolicy()
print("State: {}\nSampled Action: {}\nProbabilities [stick, hit]: {}".format(s, policy.sample_action(s), policy.get_probs([s,s],[0,1])))
# Out:
# State: (18, 6, False)
# Sampled Action: 0
# Probabilities [stick, hit]: [0.5 0.5]

# %% [markdown]
# Now implement the MC prediction algorithm with ordinary importance sampling. Use the sampling function from above to sample data from a single episode.
#
# Hint: Get probs functions may be handy. You can use `for i in tqdm(range(num_episodes))` to show a progress bar.

# %%
# %%execwritefile -a mc_autograde.py
#
# def mc_importance_sampling(env, behavior_policy, target_policy, num_episodes, discount_factor=1.0,
#                            sampling_function=sample_episode):
#     """
#     Monte Carlo prediction algorithm. Calculates the value function
#     for a given target policy using behavior policy and ordinary importance sampling.
#
#     Args:
#         env: OpenAI gym environment.
#         behavior_policy: A policy used to collect the data.
#         target_policy: A policy which value function we want to estimate.
#         num_episodes: Number of episodes to sample.
#         discount_factor: Gamma discount factor.
#         sampling_function: Function that generates data from one episode.
#
#     Returns:
#         A dictionary that maps from state -> value.
#         The state is a tuple and the value is a float.
#     """
#
#     # Keeps track of current V and count of returns for each state
#     # to calculate an update.
#     V = defaultdict(float)
#     returns_count = defaultdict(float)
#
#     returns_total = defaultdict(float)
#
#     for i in tqdm(range(num_episodes)):
#
#         states, actions, rewards, dones = sampling_function(env, behavior_policy)
#         G = 0.
#         W = 1.
#
#         for step in range(len(actions)-1, -1, -1): # A_{t-1}, R_{t}
#
#             state = states[step]
#             G = discount_factor*G + rewards[step]
#
#             returns_count[state] += 1
#             W = W * (target_policy.get_probs([state], [actions[step]]) / behavior_policy.get_probs([state], [actions[step]]))
#
#             V[state] = V[state] + (((W * G) - V[state]) / returns_count[state])
#
#             if W == 0:
#                 break
#     return V
# Out:
# Appending to mc_autograde.py

# %%
V_10k = mc_importance_sampling(env, RandomBlackjackPolicy(), SimpleBlackjackPolicy(), num_episodes=10000)
print(V_10k)
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 7054.86it/s]
# defaultdict(<class 'float'>, {(20, 10, False): array([0.43404255]), (15, 1, False): array([-0.66666667]), (16, 2, False): array([-0.53191489]), (13, 2, False): array([-0.56842105]), (19, 10, False): array([-0.77564103]), (17, 10, False): array([-0.77115987]), (15, 10, False): array([-0.7077748]), (14, 10, False): array([-0.57069409]), (16, 4, False): array([-0.73809524]), (21, 2, False): array([0.83636364]), (19, 2, False): array([-0.64102564]), (12, 2, False): array([-0.84615385]), (18, 2, True): array([-1.]), (18, 3, False): array([-0.53763441]), (14, 3, False): array([-0.56790123]), (19, 6, False): array([-0.75294118]), (14, 6, False): array([-0.36781609]), (20, 6, True): array([0.33333333]), (20, 1, False): array([0.12389381]), (20, 2, False): array([0.69230769]), (21, 7, False): array([0.67924528]), (16, 10, False): array([-0.58020478]), (14, 7, False): array([-0.63529412]), (13, 6, False): array([-0.28037383]), (18, 1, False): array([-0.42553191]), (17, 6, False): array([-0.66666667]), (20, 3, False): array([0.55357143]), (19, 6, True): array([-1.]), (19, 3, False): array([-0.58461538]), (17, 3, False): array([-0.82758621]), (17, 2, False): array([-0.57142857]), (15, 10, True): array([-0.87804878]), (12, 10, False): array([-0.63888889]), (18, 5, False): array([-0.69444444]), (13, 5, False): array([-0.47619048]), (21, 10, True): array([0.77037037]), (16, 6, False): array([-0.85]), (21, 6, False): array([0.78571429]), (12, 6, False): array([-0.63917526]), (17, 4, False): array([-0.55913978]), (14, 5, False): array([-0.79518072]), (13, 4, False): array([-0.53488372]), (15, 4, True): array([-0.30769231]), (20, 6, False): array([0.75213675]), (16, 7, True): array([-1.6]), (18, 8, False): array([-0.73809524]), (14, 8, False): array([-0.42696629]), (15, 5, False): array([-0.7184466]), (20, 10, True): array([0.34285714]), (13, 10, False): array([-0.58139535]), (12, 7, True): array([0.]), (18, 7, False): array([-0.56790123]), (20, 7, False): array([0.72727273]), (19, 7, False): array([-0.87640449]), (16, 7, False): array([-0.93150685]), (21, 10, False): array([0.92537313]), (19, 1, False): array([-0.68421053]), (21, 1, True): array([0.29787234]), (14, 2, False): array([-0.5]), (15, 6, False): array([-0.53061224]), (17, 3, True): array([-0.94117647]), (19, 8, False): array([-0.4]), (13, 8, False): array([-0.64285714]), (13, 7, False): array([-0.66666667]), (21, 7, True): array([0.81818182]), (16, 8, False): array([-0.62650602]), (17, 5, False): array([-0.80952381]), (18, 10, False): array([-0.59347181]), (14, 9, False): array([-0.75362319]), (17, 9, False): array([-0.73809524]), (13, 9, False): array([-0.46341463]), (18, 6, False): array([-0.68421053]), (13, 1, False): array([-0.57777778]), (12, 1, False): array([-0.52941176]), (19, 1, True): array([-0.66666667]), (19, 9, False): array([-0.56338028]), (12, 3, False): array([-0.43373494]), (12, 9, False): array([-0.72164948]), (19, 9, True): array([-1.18952467e-16]), (20, 8, False): array([0.77310924]), (14, 1, False): array([-0.81395349]), (15, 1, True): array([-1.09090909]), (13, 1, True): array([-2.85714286]), (16, 3, False): array([-0.63366337]), (21, 9, False): array([0.93939394]), (16, 9, False): array([-0.4494382]), (19, 5, False): array([-0.72727273]), (21, 5, True): array([1.10638298]), (18, 9, True): array([0.26666667]), (15, 9, True): array([0.]), (12, 5, False): array([-0.64367816]), (13, 3, False): array([-0.79452055]), (17, 8, False): array([-0.43478261]), (12, 8, False): array([-0.7012987]), (18, 2, False): array([-0.35820896]), (15, 2, False): array([-0.59770115]), (21, 4, False): array([0.68852459]), (20, 4, False): array([0.75968992]), (16, 6, True): array([-1.5]), (21, 1, False): array([0.84375]), (19, 3, True): array([-0.53333333]), (12, 4, False): array([-0.0733945]), (20, 9, False): array([0.72268908]), (15, 7, False): array([-0.5]), (12, 7, False): array([-0.63829787]), (21, 4, True): array([0.87804878]), (15, 4, False): array([-0.57142857]), (15, 3, True): a ...

# %%
print(min(V_10k.values()))
print(max(V_10k.values()))
# Out:
# [-4.]
# [2.]

# %%
# %%time
# Let's run your code one time
V_10k = mc_importance_sampling(env, RandomBlackjackPolicy(), SimpleBlackjackPolicy(), num_episodes=10000)
V_500k = mc_importance_sampling(env, RandomBlackjackPolicy(), SimpleBlackjackPolicy(), num_episodes=500000)
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 7027.87it/s]
# 100%|██████████| 500000/500000 [01:11<00:00, 6969.53it/s]
# CPU times: user 1min 13s, sys: 80 ms, total: 1min 13s
# Wall time: 1min 13s

# %%
print(min(V_500k.values()))
print(max(V_500k.values()))
# Out:
# [-0.97413793]
# [1.36087799]

# %% [markdown]
# Plot the V function. Do the plots look like what you expected?

# %%
fig = plt.figure(0)
ax = fig.add_subplot(111, projection='3d')
X = np.arange(min([int(i[0]) for i in V_500k.keys()]), max([int(i[0])for i in V_10k.keys()])+1)
Y = np.arange(min([i[1] for i in V_500k.keys()]), max([i[1] for i in V_10k.keys()])+1)
Z = np.zeros([len(X), len(Y), 2])

for i, x in enumerate(X):
    for j,y in enumerate(Y):
        for k,z in enumerate([False, True]):
              Z[i, j, k] = V_500k[x, y, z]

X, Y = np.meshgrid(X, Y)
ax.plot_surface(X, Y, Z[:, :, 1])

ax.set_title('After 500K episodes, usable ace')
ax.set_zlim(-1, 1)
ax.set_xlabel("player")
ax.set_ylabel("dealer")
# Out:
# Text(0.5, 0, 'dealer')

# %% [markdown]
# If you want to test/submit your solution **restart the kernel, run all cells and submit the mc_autograde.py file into codegrade.**
